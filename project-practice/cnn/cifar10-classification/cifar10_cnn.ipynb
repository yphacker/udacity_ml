# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 23s - loss: 1.6217 - acc: 0.4103 - val_loss: 1.3530 - val_acc: 0.5122
#
# Epoch 00001: val_loss improved from inf to 1.35296, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 24s - loss: 1.2999 - acc: 0.5351 - val_loss: 1.3265 - val_acc: 0.5430
#
# Epoch 00002: val_loss improved from 1.35296 to 1.32654, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 24s - loss: 1.1754 - acc: 0.5811 - val_loss: 1.1536 - val_acc: 0.5882
#
# Epoch 00003: val_loss improved from 1.32654 to 1.15364, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 23s - loss: 1.1096 - acc: 0.6072 - val_loss: 1.0263 - val_acc: 0.6464
#
# Epoch 00004: val_loss improved from 1.15364 to 1.02634, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 24s - loss: 1.0681 - acc: 0.6246 - val_loss: 0.9770 - val_acc: 0.6552
#
# Epoch 00005: val_loss improved from 1.02634 to 0.97698, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 24s - loss: 1.0450 - acc: 0.6379 - val_loss: 1.1703 - val_acc: 0.5814
#
# Epoch 00006: val_loss did not improve from 0.97698
# Epoch 7/100
#  - 22s - loss: 1.0325 - acc: 0.6423 - val_loss: 1.2091 - val_acc: 0.5866
#
# Epoch 00007: val_loss did not improve from 0.97698
# Epoch 8/100
#  - 22s - loss: 1.0279 - acc: 0.6471 - val_loss: 0.9999 - val_acc: 0.6562
#
# Epoch 00008: val_loss did not improve from 0.97698
# Epoch 9/100
#  - 23s - loss: 1.0315 - acc: 0.6469 - val_loss: 1.0593 - val_acc: 0.6424
#
# Epoch 00009: val_loss did not improve from 0.97698
# Epoch 10/100
#  - 22s - loss: 1.0259 - acc: 0.6542 - val_loss: 0.9844 - val_acc: 0.6644
#
# Epoch 00010: val_loss did not improve from 0.97698
# Epoch 11/100
#  - 22s - loss: 1.0336 - acc: 0.6514 - val_loss: 1.0575 - val_acc: 0.6398
#
# Epoch 00011: val_loss did not improve from 0.97698
# Epoch 12/100
#  - 23s - loss: 1.0356 - acc: 0.6497 - val_loss: 1.0210 - val_acc: 0.6550
#
# Epoch 00012: val_loss did not improve from 0.97698
# Epoch 13/100
#  - 22s - loss: 1.0488 - acc: 0.6475 - val_loss: 1.1040 - val_acc: 0.6524
#
# Epoch 00013: val_loss did not improve from 0.97698
# Epoch 14/100
#  - 21s - loss: 1.0642 - acc: 0.6419 - val_loss: 1.5076 - val_acc: 0.5984
#
# Epoch 00014: val_loss did not improve from 0.97698
# Epoch 15/100
#  - 21s - loss: 1.0731 - acc: 0.6421 - val_loss: 1.0573 - val_acc: 0.6222
#
# Epoch 00015: val_loss did not improve from 0.97698
# Epoch 16/100
#  - 21s - loss: 1.0973 - acc: 0.6364 - val_loss: 1.1430 - val_acc: 0.6086
#
# Epoch 00016: val_loss did not improve from 0.97698
# Epoch 17/100
#  - 22s - loss: 1.1199 - acc: 0.6296 - val_loss: 0.9662 - val_acc: 0.6788
#
# Epoch 00017: val_loss improved from 0.97698 to 0.96622, saving model to model.weights.best.hdf5
# Epoch 18/100
#  - 21s - loss: 1.1315 - acc: 0.6258 - val_loss: 1.1499 - val_acc: 0.6326
#
# Epoch 00018: val_loss did not improve from 0.96622
# Epoch 19/100
#  - 22s - loss: 1.1572 - acc: 0.6169 - val_loss: 1.3768 - val_acc: 0.6180
#
# Epoch 00019: val_loss did not improve from 0.96622
# Epoch 20/100
#  - 21s - loss: 1.1752 - acc: 0.6112 - val_loss: 1.1487 - val_acc: 0.6156
#
# Epoch 00020: val_loss did not improve from 0.96622
# Epoch 21/100
#  - 21s - loss: 1.1830 - acc: 0.6105 - val_loss: 1.4070 - val_acc: 0.5230
#
# Epoch 00021: val_loss did not improve from 0.96622
# Epoch 22/100
#  - 21s - loss: 1.1986 - acc: 0.6042 - val_loss: 1.1375 - val_acc: 0.6370
#
# Epoch 00022: val_loss did not improve from 0.96622
# Epoch 23/100
#  - 21s - loss: 1.2102 - acc: 0.5995 - val_loss: 1.2236 - val_acc: 0.6088
#
# Epoch 00023: val_loss did not improve from 0.96622
# Epoch 24/100
#  - 21s - loss: 1.2231 - acc: 0.5926 - val_loss: 1.1191 - val_acc: 0.6150
#
# Epoch 00024: val_loss did not improve from 0.96622
# Epoch 25/100
#  - 21s - loss: 1.2347 - acc: 0.5914 - val_loss: 1.4203 - val_acc: 0.5424
#
# Epoch 00025: val_loss did not improve from 0.96622
# Epoch 26/100
#  - 22s - loss: 1.2619 - acc: 0.5845 - val_loss: 1.2885 - val_acc: 0.5634
#
# Epoch 00026: val_loss did not improve from 0.96622
# Epoch 27/100
#  - 21s - loss: 1.2685 - acc: 0.5815 - val_loss: 1.1602 - val_acc: 0.6486
#
# Epoch 00027: val_loss did not improve from 0.96622
# Epoch 28/100
#  - 22s - loss: 1.2927 - acc: 0.5700 - val_loss: 1.3306 - val_acc: 0.5470
#
# Epoch 00028: val_loss did not improve from 0.96622
# Epoch 29/100
#  - 22s - loss: 1.3105 - acc: 0.5666 - val_loss: 1.1460 - val_acc: 0.6050
#
# Epoch 00029: val_loss did not improve from 0.96622
# Epoch 30/100
#  - 23s - loss: 1.3248 - acc: 0.5633 - val_loss: 1.2901 - val_acc: 0.5660
#
# Epoch 00030: val_loss did not improve from 0.96622
# Epoch 31/100
#  - 22s - loss: 1.3299 - acc: 0.5605 - val_loss: 1.9034 - val_acc: 0.5814
#
# Epoch 00031: val_loss did not improve from 0.96622
# Epoch 32/100
#  - 23s - loss: 1.3545 - acc: 0.5523 - val_loss: 1.2765 - val_acc: 0.5566
#
# Epoch 00032: val_loss did not improve from 0.96622
# Epoch 33/100
#  - 23s - loss: 1.3754 - acc: 0.5437 - val_loss: 1.2912 - val_acc: 0.5600
#
# Epoch 00033: val_loss did not improve from 0.96622
# Epoch 34/100
#  - 21s - loss: 1.3732 - acc: 0.5445 - val_loss: 1.3028 - val_acc: 0.5556
#
# Epoch 00034: val_loss did not improve from 0.96622
# Epoch 35/100
#  - 22s - loss: 1.3844 - acc: 0.5412 - val_loss: 1.4834 - val_acc: 0.5922
#
# Epoch 00035: val_loss did not improve from 0.96622
# Epoch 36/100
#  - 21s - loss: 1.4086 - acc: 0.5328 - val_loss: 1.7302 - val_acc: 0.4970
#
# Epoch 00036: val_loss did not improve from 0.96622
# Epoch 37/100
#  - 22s - loss: 1.4263 - acc: 0.5259 - val_loss: 1.4923 - val_acc: 0.4856
#
# Epoch 00037: val_loss did not improve from 0.96622
# Epoch 38/100
#  - 21s - loss: 1.4336 - acc: 0.5237 - val_loss: 1.1645 - val_acc: 0.6002
#
# Epoch 00038: val_loss did not improve from 0.96622
# Epoch 39/100
#  - 21s - loss: 1.4585 - acc: 0.5127 - val_loss: 1.5252 - val_acc: 0.5328
#
# Epoch 00039: val_loss did not improve from 0.96622
# Epoch 40/100
#  - 21s - loss: 1.4645 - acc: 0.5148 - val_loss: 1.4344 - val_acc: 0.5614
#
# Epoch 00040: val_loss did not improve from 0.96622
# Epoch 41/100
#  - 21s - loss: 1.4735 - acc: 0.5088 - val_loss: 1.5048 - val_acc: 0.5012
#
# Epoch 00041: val_loss did not improve from 0.96622
# Epoch 42/100
#  - 21s - loss: 1.4931 - acc: 0.5034 - val_loss: 1.5811 - val_acc: 0.4544
#
# Epoch 00042: val_loss did not improve from 0.96622
# Epoch 43/100
#  - 21s - loss: 1.4935 - acc: 0.5024 - val_loss: 1.3448 - val_acc: 0.5426
#
# Epoch 00043: val_loss did not improve from 0.96622
# Epoch 44/100
#  - 21s - loss: 1.4976 - acc: 0.4992 - val_loss: 1.4085 - val_acc: 0.5452
#
# Epoch 00044: val_loss did not improve from 0.96622
# Epoch 45/100
#  - 21s - loss: 1.5194 - acc: 0.4901 - val_loss: 1.2894 - val_acc: 0.5564
#
# Epoch 00045: val_loss did not improve from 0.96622
# Epoch 46/100
#  - 21s - loss: 1.5229 - acc: 0.4924 - val_loss: 1.2484 - val_acc: 0.5738
#
# Epoch 00046: val_loss did not improve from 0.96622
# Epoch 47/100
#  - 21s - loss: 1.5421 - acc: 0.4844 - val_loss: 1.4140 - val_acc: 0.4850
#
# Epoch 00047: val_loss did not improve from 0.96622
# Epoch 48/100
#  - 21s - loss: 1.5282 - acc: 0.4871 - val_loss: 1.5765 - val_acc: 0.5122
#
# Epoch 00048: val_loss did not improve from 0.96622
# Epoch 49/100
#  - 23s - loss: 1.5290 - acc: 0.4863 - val_loss: 1.4604 - val_acc: 0.4774
#
# Epoch 00049: val_loss did not improve from 0.96622
# Epoch 50/100
#  - 21s - loss: 1.5509 - acc: 0.4803 - val_loss: 1.5769 - val_acc: 0.4696
#
# Epoch 00050: val_loss did not improve from 0.96622
# Epoch 51/100
#  - 22s - loss: 1.5587 - acc: 0.4827 - val_loss: 1.4097 - val_acc: 0.5258
#
# Epoch 00051: val_loss did not improve from 0.96622
# Epoch 52/100
#  - 22s - loss: 1.5626 - acc: 0.4749 - val_loss: 1.3025 - val_acc: 0.5416
#
# Epoch 00052: val_loss did not improve from 0.96622
# Epoch 53/100
#  - 23s - loss: 1.5705 - acc: 0.4728 - val_loss: 3.2539 - val_acc: 0.4206
#
# Epoch 00053: val_loss did not improve from 0.96622
# Epoch 54/100
#  - 24s - loss: 1.5700 - acc: 0.4779 - val_loss: 1.5321 - val_acc: 0.4604
#
# Epoch 00054: val_loss did not improve from 0.96622
# Epoch 55/100
#  - 23s - loss: 1.5781 - acc: 0.4700 - val_loss: 1.5725 - val_acc: 0.4680
#
# Epoch 00055: val_loss did not improve from 0.96622
# Epoch 56/100
#  - 23s - loss: 1.5723 - acc: 0.4732 - val_loss: 1.4603 - val_acc: 0.4798
#
# Epoch 00056: val_loss did not improve from 0.96622
# Epoch 57/100
#  - 23s - loss: 1.5766 - acc: 0.4675 - val_loss: 1.3471 - val_acc: 0.5356
#
# Epoch 00057: val_loss did not improve from 0.96622
# Epoch 58/100
#  - 23s - loss: 1.5924 - acc: 0.4605 - val_loss: 1.6234 - val_acc: 0.4272
# Epoch 00058: val_loss did not improve from 0.96622
# Epoch 59/100
#  - 21s - loss: 1.5993 - acc: 0.4598 - val_loss: 1.4323 - val_acc: 0.4852
#
# Epoch 00059: val_loss did not improve from 0.96622
# Epoch 60/100
#  - 24s - loss: 1.6071 - acc: 0.4560 - val_loss: 1.5857 - val_acc: 0.4736
#
# Epoch 00060: val_loss did not improve from 0.96622
# Epoch 61/100
#  - 23s - loss: 1.6131 - acc: 0.4551 - val_loss: 1.3703 - val_acc: 0.5174
#
# Epoch 00061: val_loss did not improve from 0.96622
# Epoch 62/100
#  - 21s - loss: 1.6314 - acc: 0.4487 - val_loss: 1.3253 - val_acc: 0.5400
#
# Epoch 00062: val_loss did not improve from 0.96622
# Epoch 63/100
#  - 21s - loss: 1.6115 - acc: 0.4586 - val_loss: 1.3469 - val_acc: 0.5200
#
# Epoch 00063: val_loss did not improve from 0.96622
# Epoch 64/100
#  - 21s - loss: 1.6169 - acc: 0.4511 - val_loss: 1.5159 - val_acc: 0.4884
#
# Epoch 00064: val_loss did not improve from 0.96622
# Epoch 65/100
#  - 21s - loss: 1.6249 - acc: 0.4500 - val_loss: 2.6017 - val_acc: 0.4432
#
# Epoch 00065: val_loss did not improve from 0.96622
# Epoch 66/100
#  - 23s - loss: 1.6360 - acc: 0.4493 - val_loss: 1.4355 - val_acc: 0.4776
#
# Epoch 00066: val_loss did not improve from 0.96622
# Epoch 67/100
#  - 24s - loss: 1.6568 - acc: 0.4379 - val_loss: 1.4196 - val_acc: 0.5316
#
# Epoch 00067: val_loss did not improve from 0.96622
# Epoch 68/100
#  - 25s - loss: 1.6683 - acc: 0.4332 - val_loss: 4.0896 - val_acc: 0.3038
#
# Epoch 00068: val_loss did not improve from 0.96622
# Epoch 69/100
#  - 24s - loss: 1.6670 - acc: 0.4330 - val_loss: 1.3760 - val_acc: 0.5112
#
# Epoch 00069: val_loss did not improve from 0.96622
# Epoch 70/100
#  - 25s - loss: 1.6635 - acc: 0.4315 - val_loss: 1.8215 - val_acc: 0.3520
#
# Epoch 00070: val_loss did not improve from 0.96622
# Epoch 71/100
#  - 25s - loss: 1.6519 - acc: 0.4361 - val_loss: 1.8935 - val_acc: 0.3830
#
# Epoch 00071: val_loss did not improve from 0.96622
# Epoch 72/100
#  - 27s - loss: 1.6712 - acc: 0.4323 - val_loss: 1.3594 - val_acc: 0.5418
#
# Epoch 00072: val_loss did not improve from 0.96622
# Epoch 73/100
#  - 25s - loss: 1.6633 - acc: 0.4345 - val_loss: 1.4327 - val_acc: 0.5426
#
# Epoch 00073: val_loss did not improve from 0.96622
# Epoch 74/100
#  - 22s - loss: 1.6699 - acc: 0.4316 - val_loss: 1.5122 - val_acc: 0.4502
#
# Epoch 00074: val_loss did not improve from 0.96622
# Epoch 75/100
#  - 23s - loss: 1.6716 - acc: 0.4257 - val_loss: 1.3933 - val_acc: 0.4732
#
# Epoch 00075: val_loss did not improve from 0.96622
# Epoch 76/100
#  - 21s - loss: 1.6805 - acc: 0.4268 - val_loss: 1.3730 - val_acc: 0.4970
#
# Epoch 00076: val_loss did not improve from 0.96622
# Epoch 77/100
#  - 21s - loss: 1.6682 - acc: 0.4250 - val_loss: 1.6498 - val_acc: 0.4256
#
# Epoch 00077: val_loss did not improve from 0.96622
# Epoch 78/100
#  - 21s - loss: 1.6711 - acc: 0.4314 - val_loss: 1.4902 - val_acc: 0.4762
#
# Epoch 00078: val_loss did not improve from 0.96622
# Epoch 79/100
#  - 21s - loss: 1.6884 - acc: 0.4172 - val_loss: 1.7021 - val_acc: 0.4288
#
# Epoch 00079: val_loss did not improve from 0.96622
# Epoch 80/100
#  - 21s - loss: 1.7115 - acc: 0.4138 - val_loss: 1.5114 - val_acc: 0.4586
#
# Epoch 00080: val_loss did not improve from 0.96622
# Epoch 81/100
#  - 21s - loss: 1.6972 - acc: 0.4132 - val_loss: 2.1988 - val_acc: 0.3798
#
# Epoch 00081: val_loss did not improve from 0.96622
# Epoch 82/100
#  - 22s - loss: 1.6921 - acc: 0.4182 - val_loss: 1.5761 - val_acc: 0.4790
#
# Epoch 00082: val_loss did not improve from 0.96622
# Epoch 83/100
#  - 23s - loss: 1.6886 - acc: 0.4132 - val_loss: 1.7636 - val_acc: 0.4232
#
# Epoch 00083: val_loss did not improve from 0.96622
# Epoch 84/100
#  - 22s - loss: 1.6959 - acc: 0.4189 - val_loss: 1.4901 - val_acc: 0.4786
#
# Epoch 00084: val_loss did not improve from 0.96622
# Epoch 85/100
#  - 25s - loss: 1.7015 - acc: 0.4135 - val_loss: 1.5830 - val_acc: 0.4594
#
# Epoch 00085: val_loss did not improve from 0.96622
# Epoch 86/100
#  - 24s - loss: 1.7074 - acc: 0.4136 - val_loss: 1.4953 - val_acc: 0.4590
#
# Epoch 00086: val_loss did not improve from 0.96622
# Epoch 87/100
#  - 24s - loss: 1.7033 - acc: 0.4111 - val_loss: 1.4956 - val_acc: 0.4630
#
# Epoch 00087: val_loss did not improve from 0.96622
# Epoch 88/100
#  - 24s - loss: 1.6997 - acc: 0.4126 - val_loss: 1.5690 - val_acc: 0.4224
#
# Epoch 00088: val_loss did not improve from 0.96622
# Epoch 89/100
#  - 24s - loss: 1.7157 - acc: 0.4065 - val_loss: 1.6417 - val_acc: 0.3942
#
# Epoch 00089: val_loss did not improve from 0.96622
# Epoch 90/100
#  - 24s - loss: 1.7299 - acc: 0.4032 - val_loss: 1.6746 - val_acc: 0.3990
#
# Epoch 00090: val_loss did not improve from 0.96622
# Epoch 91/100
#  - 23s - loss: 1.7314 - acc: 0.4008 - val_loss: 1.7521 - val_acc: 0.3578
#
# Epoch 00091: val_loss did not improve from 0.96622
# Epoch 92/100
#  - 25s - loss: 1.7225 - acc: 0.4063 - val_loss: 1.4470 - val_acc: 0.5006
#
# Epoch 00092: val_loss did not improve from 0.96622
# Epoch 93/100
#  - 24s - loss: 1.7050 - acc: 0.4066 - val_loss: 1.5850 - val_acc: 0.4172
#
# Epoch 00093: val_loss did not improve from 0.96622
# Epoch 94/100
#  - 24s - loss: 1.7335 - acc: 0.3965 - val_loss: 1.5728 - val_acc: 0.4326
#
# Epoch 00094: val_loss did not improve from 0.96622
# Epoch 95/100
#  - 23s - loss: 1.7566 - acc: 0.3905 - val_loss: 1.5095 - val_acc: 0.4610
#
# Epoch 00095: val_loss did not improve from 0.96622
# Epoch 96/100
#  - 23s - loss: 1.7454 - acc: 0.3921 - val_loss: 2.2018 - val_acc: 0.4154
#
# Epoch 00096: val_loss did not improve from 0.96622
# Epoch 97/100
#  - 25s - loss: 1.7445 - acc: 0.3928 - val_loss: 1.7997 - val_acc: 0.4428
#
# Epoch 00097: val_loss did not improve from 0.96622
# Epoch 98/100
#  - 25s - loss: 1.7371 - acc: 0.3921 - val_loss: 1.6115 - val_acc: 0.4984
#
# Epoch 00098: val_loss did not improve from 0.96622
# Epoch 99/100
#  - 23s - loss: 1.7652 - acc: 0.3861 - val_loss: 3.7364 - val_acc: 0.4174
#
# Epoch 00099: val_loss did not improve from 0.96622
# Epoch 100/100
#  - 26s - loss: 1.7739 - acc: 0.3856 - val_loss: 1.8114 - val_acc: 0.3078
#
# Epoch 00100: val_loss did not improve from 0.96622

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6619

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
